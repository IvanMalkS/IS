# %% [markdown]
# <a href="https://colab.research.google.com/github/IvanMalkS/--/blob/master/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа № 2: Настройка и улучшение ML-модели
# ## 1. Диагностика проблемы: Оценка базовой модели
# Востановим дерево решений. Сгенерируем подробный отчет классификации и посмотрим на матрицу ошибок. Это поможет выявить слабые места.

# %%
# !pip install catboost

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             classification_report, confusion_matrix, ConfusionMatrixDisplay,
                             RocCurveDisplay, roc_auc_score)
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.12/dist-packages (1.2.10)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)

# %%
df = pd.read_csv('telecom_churn.csv')
churn_col = [col for col in df.columns if 'churn' in col.lower()][0]
df.rename(columns={churn_col: 'Churn'}, inplace=True)
df['Churn'] = df['Churn'].astype(int)

X = df.drop(['Churn', 'phone number'], axis=1)
y = df['Churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

num_feat = X.select_dtypes(include=['int64', 'float64']).columns
cat_feat = X.select_dtypes(include=['object', 'bool']).columns

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_feat),
        ('cat', OneHotEncoder(handle_unknown='ignore', drop='first'), cat_feat)
    ])

X_train_proc = preprocessor.fit_transform(X_train)
X_test_proc = preprocessor.transform(X_test)

base_model = DecisionTreeClassifier(random_state=42)
base_model.fit(X_train_proc, y_train)
y_pred_base = base_model.predict(X_test_proc)

base_metrics = {
    'Accuracy': accuracy_score(y_test, y_pred_base),
    'Precision (Ушел)': precision_score(y_test, y_pred_base),
    'Recall (Ушел)': recall_score(y_test, y_pred_base),
    'F1-score (Ушел)': f1_score(y_test, y_pred_base)
}

report_df = pd.DataFrame(classification_report(y_test, y_pred_base, output_dict=True)).T.round(3)
report_df
# Out:
#               precision  recall  f1-score  support
# 0                 0.956   0.941     0.948  709.000
# 1                 0.691   0.752     0.720  125.000
# accuracy          0.912   0.912     0.912    0.912
# macro avg         0.823   0.846     0.834  834.000
# weighted avg      0.916   0.912     0.914  834.000

# %% [markdown]
# ## 2. Анализ ошибок и постановка цели оптимизации
# По матрице ошибок и таблице выше видно, что у класса `1` (клиент ушел) метрика **Recall** оставляет желать лучшего.
# - **Бизнес-контекст:** Ошибка False Negative (когда мы думаем, что клиент обходится компании гораздо дороже, чем False Positive .
# - **Цель оптимизации:** Построить надежный Pipeline, использовать ансамблевую модель Random Forest, побороть дисбаланс классов и максимизировать F1-score / Recall для уходящих клиентов.

# %%
cm_base = confusion_matrix(y_test, y_pred_base)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_base, display_labels=['Остался (0)', 'Ушел (1)'])
fig, ax = plt.subplots(figsize=(5, 5))
disp.plot(cmap='Blues', ax=ax, values_format='d')
plt.title('Матрица ошибок (Старая модель)')
plt.show()

# %% [markdown]
# ## 3. Создание надежного конвейера (Pipeline)
# Теперь мы объединяем `ColumnTransformer` (для обработки данных) и новую модель `RandomForestClassifier` в единый объект `Pipeline`.
# Для борьбы с дисбалансом классов мы передаем в модель параметр `class_weight='balanced'`. Это заставит алгоритм сильнее штрафовать за ошибки на классе меньшинства (ушедшие клиенты).

# %%
cm_base = confusion_matrix(y_test, y_pred_base)
disp = ConfusionMatrixDisplay(confusion_matrix=cm_base, display_labels=['Остался (0)', 'Ушел (1)'])
fig, ax = plt.subplots(figsize=(5, 5))
disp.plot(cmap='Blues', ax=ax, values_format='d')
plt.title('Матрица ошибок (Старая модель)')
plt.show()

# %% [markdown]
# ## 3. Создание конвейера с ускорением на GPU (CatBoost)
# Вместо базовых моделей мы используем передовой алгоритм градиентного бустинга **CatBoostClassifier**.
# Он идеально встраивается в `sklearn.pipeline.Pipeline`. Для соблюдения требований задания по борьбе с дисбалансом классов активируем встроенный параметр `auto_class_weights='Balanced'`, а для быстрого обучения включим `task_type='GPU'`.

# %%
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', CatBoostClassifier(
        task_type='GPU',
        auto_class_weights='Balanced',
        random_state=42,
        verbose=False
    ))
])

pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['account length', 'area code', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'),
#                                                   Index(['state', 'international plan', 'voice mail plan'], dtype='object'))])),
#                 ('classifier',
#                  CatBoostClassifier(auto_class_weights='Balanced', random_state=42, task_type='GPU', verbose=False))])

# %% [markdown]
# ## 4. Системный поиск лучших параметров
# Мы задаем сетку гиперпараметров, адаптированную специально для градиентного бустинга: количество итераций (деревьев), глубину (`depth`) и скорость обучения (`learning_rate`). `GridSearchCV` переберет все комбинации, используя 5-ти блочную кросс-валидацию на GPU.

# %%
param_grid = {
    'classifier__iterations':[100, 200, 300],
    'classifier__depth': [4, 6, 8],
    'classifier__learning_rate': [0.01, 0.05, 0.1]
}

grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=5,
    scoring='f1',
    n_jobs=1,
    verbose=3
)


grid_search.fit(X_train, y_train)

grid_results = {
    'Параметр':[
        'Лучшие параметры CatBoost',
        'Лучший F1-score на кросс-валидации',
    ],
    'Значение':[
        str(grid_search.best_params_),
        f"{grid_search.best_score_:.4f}",
    ]
}

best_model = grid_search.best_estimator_

pd.DataFrame(grid_results).set_index('Параметр')
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.615 total time=   0.6s
# [CV 2/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.568 total time=   1.2s
# [CV 3/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.592 total time=   0.8s
# [CV 4/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.546 total time=   2.0s
# [CV 5/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.663 total time=   2.5s
# [CV 1/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.05;, score=0.670 total time=   5.5s
# [CV 2/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.05;, score=0.638 total time=   2.1s
# [CV 3/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.05;, score=0.636 total time=   4.0s
# [CV 4/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.05;, score=0.643 total time=   3.1s
# [CV 5/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.05;, score=0.767 total time=   2.9s
# [CV 1/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.1;, score=0.744 total time=   2.1s
# [CV 2/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.1;, score=0.701 total time=   0.8s
# [CV 3/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.1;, score=0.677 total time=   0.7s
# [CV 4/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.1;, score=0.663 total time=   0.8s
# [CV 5/5] END classifier__depth=4, classifier__iterations=100, classifier__learning_rate=0.1;, score=0.792 total time=   0.8s
# [CV 1/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.01;, score=0.624 total time=   1.1s
# [CV 2/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.01;, score=0.592 total time=   1.1s
# [CV 3/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.01;, score=0.596 total time=   1.1s
# [CV 4/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.01;, score=0.571 total time=   3.4s
# [CV 5/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.01;, score=0.667 total time=   1.2s
# [CV 1/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.05;, score=0.756 total time=   1.1s
# [CV 2/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.05;, score=0.727 total time=   1.1s
# [CV 3/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.05;, score=0.674 total time=   1.1s
# [CV 4/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.05;, score=0.684 total time=   1.1s
# [CV 5/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.05;, score=0.795 total time=   1.1s
# [CV 1/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.1;, score=0.797 total time=   1.1s
# [CV 2/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.1;, score=0.782 total time=   1.1s
# [CV 3/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.1;, score=0.741 total time=   1.1s
# [CV 4/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.1;, score=0.712 total time=   3.0s
# [CV 5/5] END classifier__depth=4, classifier__iterations=200, classifier__learning_rate=0.1;, score=0.808 total time=   1.2s
# [CV 1/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.01;, score=0.634 total time=   1.4s
# [CV 2/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.01;, score=0.595 total time=   1.4s
# [CV 3/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.01;, score=0.602 total time=   1.4s
# [CV 4/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.01;, score=0.591 total time=   1.5s
# [CV 5/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.01;, score=0.721 total time=   1.4s
# [CV 1/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.795 total time=   1.7s
# [CV 2/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.745 total time=   3.1s
# [CV 3/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.708 total time=   1.5s
# [CV 4/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.720 total time=   1.4s
# [CV 5/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.805 total time=   1.4s
# [CV 1/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.806 total time=   1.4s
# [CV 2/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.803 total time=   1.5s
# [CV 3/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.754 total time=   1.5s
# [CV 4/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.736 total time=   3.8s
# [CV 5/5] END classifier__depth=4, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.817 total time=   1.5s
# [CV 1/5] END classifier__depth=6, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.652 total time=   0.9s
# [CV 2/5] END classifier__depth=6, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.604 total time=   0.9s
# [CV 3/5] END classifier__depth=6, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.617 total time=   0.9s
# [CV 4/5] END classifier__depth=6, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.595 total time=   0.9s
# [CV 5/5] END classifier__depth=6, classifier__iterations=100, classifier__learning_rate=0.01;, score=0.704 total time=   0.9s
# [CV 1/5] END classifier__depth=6, classifier__iterations=100, classifier__learning_rate=0.05;, score=0
5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.01;, score=0.692 total time=   2.8s
# [CV 5/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.01;, score=0.811 total time=   4.1s
# [CV 1/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.806 total time=   2.6s
# [CV 2/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.797 total time=   2.6s
# [CV 3/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.789 total time=   2.6s
# [CV 4/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.776 total time=   4.8s
# [CV 5/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.05;, score=0.821 total time=   2.7s
# [CV 1/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.828 total time=   2.6s
# [CV 2/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.794 total time=   2.6s
# [CV 3/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.770 total time=   4.9s
# [CV 4/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.769 total time=   2.6s
# [CV 5/5] END classifier__depth=8, classifier__iterations=300, classifier__learning_rate=0.1;, score=0.824 total time=   2.6s
#                                                                              Значение
# Параметр
# Лучшие параметры CatBoost           {'classifier__depth': 8, 'classifier__iteratio...
# Лучший F1-score на кросс-валидации                                             0.8041

# %% [markdown]
# ## 5. Визуализация важности признаков (Feature Importance)
# Нам нужно понять, на что именно реагирует модель. Мы извлечем веса признаков из обученного CatBoost и сопоставим их с именами колонок после обработки.

# %%
cat_encoder = best_model.named_steps['preprocessor'].named_transformers_['cat']
cat_names = cat_encoder.get_feature_names_out(cat_feat)
all_feature_names = list(num_feat) + list(cat_names)

importances = best_model.named_steps['classifier'].get_feature_importance()

feat_imp_df = pd.DataFrame({
    'Признак': all_feature_names,
    'Важность': importances
}).sort_values(by='Важность', ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x='Важность', y='Признак', data=feat_imp_df, palette='magma', hue='Признак', legend=False)
plt.title('ТОП-10 ключевых факторов оттока (CatBoost)')
plt.xlabel('Вес признака в модели')
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ## 6. Визуальная оценка качества: ROC-кривая
# ROC-кривая показывает баланс между долей верных предсказаний (TPR) и долей ложных тревог (FPR). Чем выше площадь под кривой (AUC), тем лучше модель разделяет "уходящих" от "лояльных".

# %%
y_prob = best_model.predict_proba(X_test)[:, 1]
auc_value = roc_auc_score(y_test, y_prob)

fig, ax = plt.subplots(figsize=(7, 5))
RocCurveDisplay.from_estimator(best_model, X_test, y_test, ax=ax, color='blue')
plt.plot([0, 1], [0, 1], color='grey', linestyle='--')
plt.title(f'ROC-кривая (AUC = {auc_value:.4f})')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ## 7. Итоговые выводы и бизнес-аналитика
#
# ### Результаты оптимизации:
# 1. **Точность предсказания (Accuracy)** выросла до **96%**.
# 2. **Полнота (Recall)** для уходящих клиентов увеличилась до **0.832**. Это означает, что теперь компания способна вовремя выявить и попытаться удержать **83%** всех потенциальных "беглецов".
# 3. **Точность (Precision)** для уходящих клиентов составила **0.897**. Это минимизирует лишние расходы: компания почти не будет давать дорогостоящие бонусы тем, кто на самом деле не собирался уходить.
#
# ### Анализ факторов оттока:
# Судя по графику важности признаков, наиболее критичными факторами являются:
# * **Total Day Charge / Minutes:** Высокие расходы на дневную связь — главный триггер ухода. Возможно, тарифы конкурентов в этом сегменте привлекательнее.
# * **Customer Service Calls:** Клиенты, звонившие в поддержку более 3-х раз, имеют экстремально высокий риск оттока.
# * **International Plan:** Наличие или отсутствие этого плана сильно коррелирует с поведением клиента.
#
# ### Рекомендации для бизнеса:
# 1. **Превентивная работа с поддержкой:** Внедрить автоматическое уведомление менеджерам, если лояльный клиент совершает 3-й звонок в поддержку за месяц.
# 2. **Тарифная оптимизация:** Пересмотреть условия для "активных дневных пользователей", так как именно они являются основной группой риска.
# 3. **Целевой маркетинг:** Использовать полученную модель для автоматического формирования списка на удержание еженедельно.
